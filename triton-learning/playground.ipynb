# %%
import torch
row = torch.arange(4)[:,None]
col = torch.arange(5)[None,:]
mask = (row < 2) & (col < 3)
mask
# Out:
# tensor([[ True,  True,  True, False, False],
#         [ True,  True,  True, False, False],
#         [False, False, False, False, False],
#         [False, False, False, False, False]])
