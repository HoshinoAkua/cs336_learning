# %%
import torch
from triton import language as tl
device = torch.device("cuda:0")

q = torch.randn(size=(1,2,3,4), dtype=torch.float32)
q = q.to(device)

# %%
import math
x = int(10)
math.sqrt(x)
# Out:
# 3.1622776601683795

# %%
y = torch.randn((5,3,4))

print(y.stride())
y = y.transpose(-1,-2)
print(y.stride())
# Out:
# (12, 4, 1)
# (12, 1, 4)
